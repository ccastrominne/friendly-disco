# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
plt.style.use ('seaborn-white')

# %%
def f(x):
    return 2*x

# %%
def g(x):
    return x**2

# %%
x = np.linspace(-3,3,1000)

# %%
plt.figure()
plt.plot(x,f(x), label = '$f(x)$')
plt.plot(x,g(x), label = '$g(x)$')
plt.legend()
#plt.plot(x,f(x),'bo')
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# This is a markdown and are a key feature of the Jupyter notebook. They are used to write notes and pose questions

# %%
print('hello world')
# Out:
# hello world
